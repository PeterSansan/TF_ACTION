# %% [markdown]
# # CNN手写识别
# ```
# Author: PeterSansan
# Time : 2017-4-29
# ```
# 这个例子的数据输入输出是这样变化的：
# - 1）首先输入是一张28*28的图片
# - 2)第一层先通过一层卷积层，卷积层核大小为2x2，输出为32个通道（即32个特征），这样第一层卷积层输出后为[32,28,28]的数据，即可看成是32张图片 0 - 3)再经过2x2模板的最大池化，输出为[32,14,14]的数据，即下采样了一次
# - 4)第二层先通过一层卷积层，卷积层核大小为2x2，输出为64个通道（即64个特征），这样第二层卷积层输出为64x14x14的数据，即可看成是64张下采样后的图片
# - 5）再经过2x2模板的最大池化，输出为64x7x7的数据
# - 6)最后，把数据reshape展开一维数据[64x7x7]
# - 7)加一层dropout层
# - 8）输出为类别为10的softmax层

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./../mnist/MNIST_data/", one_hot=True)
# Out:
# Extracting ./../mnist/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./../mnist/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./../mnist/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./../mnist/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %% [markdown]
# ### 卷积和池化
# 这部分卷积最难理解
#
# TensorFlow在卷积和池化上有很强的灵活性。我们怎么处理边界？步长应该设多大？在这个实例里，我们会一直使用vanilla版本。我们的卷积使用1步长（stride size），0边距（padding size）的模板，保证输出和输入是同一个大小。我们的池化用简单传统的2x2大小的模板做max pooling。为了代码更简洁，我们把这部分抽象成一个函数。

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)    #这个卷积函数后面加入relu函数


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 24214.179688, Training Accuracy= 0.32031
# Iter 2560, Minibatch Loss= 9154.766602, Training Accuracy= 0.51562
# Iter 3840, Minibatch Loss= 4155.708984, Training Accuracy= 0.74219
# Iter 5120, Minibatch Loss= 4173.262207, Training Accuracy= 0.75781
# Iter 6400, Minibatch Loss= 2755.842773, Training Accuracy= 0.85156
# Iter 7680, Minibatch Loss= 3061.447998, Training Accuracy= 0.85156
# Iter 8960, Minibatch Loss= 2907.160400, Training Accuracy= 0.85156
# Iter 10240, Minibatch Loss= 2310.236084, Training Accuracy= 0.85156
# Iter 11520, Minibatch Loss= 1419.897217, Training Accuracy= 0.86719
# Iter 12800, Minibatch Loss= 1573.836182, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 2156.866211, Training Accuracy= 0.88281
# Iter 15360, Minibatch Loss= 1103.213989, Training Accuracy= 0.90625
# Iter 16640, Minibatch Loss= 1154.810425, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 1595.521729, Training Accuracy= 0.89844
# Iter 19200, Minibatch Loss= 1625.843018, Training Accuracy= 0.93750
# Iter 20480, Minibatch Loss= 1755.059082, Training Accuracy= 0.89062
# Iter 21760, Minibatch Loss= 1782.164673, Training Accuracy= 0.89062
# Iter 23040, Minibatch Loss= 1077.896240, Training Accuracy= 0.91406
# Iter 24320, Minibatch Loss= 281.553467, Training Accuracy= 0.96875
# Iter 25600, Minibatch Loss= 609.006958, Training Accuracy= 0.93750
# Iter 26880, Minibatch Loss= 579.610596, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 694.584717, Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 1360.191650, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 1332.569214, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 1608.861450, Training Accuracy= 0.90625
# Iter 33280, Minibatch Loss= 662.057007, Training Accuracy= 0.94531
# Iter 34560, Minibatch Loss= 844.251770, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 487.088989, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 1035.567261, Training Accuracy= 0.96094
# Iter 38400, Minibatch Loss= 1316.843994, Training Accuracy= 0.92188
# Iter 39680, Minibatch Loss= 611.014160, Training Accuracy= 0.92188
# Iter 40960, Minibatch Loss= 651.121826, Training Accuracy= 0.92969
# Iter 42240, Minibatch Loss= 322.454956, Training Accuracy= 0.95312
# Iter 43520, Minibatch Loss= 306.006989, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 258.882935, Training Accuracy= 0.96875
# Iter 46080, Minibatch Loss= 628.218872, Training Accuracy= 0.92188
# Iter 47360, Minibatch Loss= 448.260712, Training Accuracy= 0.96094
# Iter 48640, Minibatch Loss= 741.951904, Training Accuracy= 0.94531
# Iter 49920, Minibatch Loss= 214.395782, Training Accuracy= 0.95312
# Iter 51200, Minibatch Loss= 1245.933228, Training Accuracy= 0.92969
# Iter 52480, Minibatch Loss= 177.900085, Training Accuracy= 0.97656
# Iter 53760, Minibatch Loss= 724.741638, Training Accuracy= 0.94531
# Iter 55040, Minibatch Loss= 1062.364746, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 225.042114, Training Accuracy= 0.97656
# Iter 57600, Minibatch Loss= 207.031616, Training Accuracy= 0.96875
# Iter 58880, Minibatch Loss= 1255.028320, Training Accuracy= 0.92188
# Iter 60160, Minibatch Loss= 436.891174, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 447.823517, Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 622.713135, Training Accuracy= 0.94531
# Iter 64000, Minibatch Loss= 214.641357, Training Accuracy= 0.98438
# Iter 65280, Minibatch Loss= 389.722290, Training Accuracy= 0.96094
# Iter 66560, Minibatch Loss= 467.425018, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 484.698151, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 300.994659, Training Accuracy= 0.97656
# Iter 70400, Minibatch Loss= 239.820160, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 607.944824, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 630.876343, Training Accuracy= 0.91406
# Iter 74240, Minibatch Loss= 276.068359, Training Accuracy= 0.96875
# Iter 75520, Minibatch Loss= 55.937393, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 217.841202, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 465.868896, Training Accuracy= 0.94531
# Iter 79360, Minibatch Loss= 1178.046509, Training Accuracy= 0.90625
# Iter 80640, Minibatch Loss= 257.388367, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 544.413574, Training Accuracy= 0.93750
# Iter 83200, Minibatch Loss= 79.850891, Training Accuracy= 0.98438
# Iter 84480, Minibatch Loss= 295.227783, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 86.204468, Training Accuracy= 0.98438
# Iter 87040, Minibatch Loss= 463.678192, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 633.709290, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 334.257629, Training Accuracy= 0.94531
# Iter 90880, Minibatch Loss= 189.688843, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 141.810028, Training Accuracy= 0.98438
# Iter 93440, Minibatch Loss= 547.920654, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 236.987503, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 143.969055, Training Accuracy= 0.98438
# Iter 97280, Minibatch Loss= 156.236755, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 366.527496, Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 305.304443, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 466.322388, Training Accuracy= 0.94531
# Iter 102400, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 103680, Minibatch Loss= 267.613037, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 92.064102, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 184.577896, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 254.435562, Training Accuracy= 0.98438
# Iter 108800, Minibatch Loss= 545.120728, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 354.894623, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 81.699585, Training Accuracy= 0.97656
# Iter 112640, Minibatch Loss= 548.650940, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 222.641403, Training Accuracy= 0.96875
# Iter 115200, Minibatch Loss= 194.707535, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 348.014282, Training Accuracy= 0.94531
# Iter 117760, Minibatch Loss= 47.778610, Training Accuracy= 0.99219
# Iter 119040, Minibatch Loss= 124.365822, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 387.971680, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 125.091293, Training Accuracy= 0.98438
# Iter 122880, Minibatch Loss= 272.204010, Training Accuracy= 0.96094
# Iter 124160, Minibatch Loss= 104.654327, Training Accuracy= 0.99219
# Iter 125440, Minibatch Loss= 398.387238, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 405.638885, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 174.269440, Training Accuracy= 0.99219
# Iter 129280, Minibatch Loss= 109.422958, Training Accuracy= 0.98438
# Iter 130560, Minibatch Loss= 58.582565, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 65.621826, Training Accuracy= 0.99219
# Iter 133120, Minibatch Loss= 161.807297, Training Accuracy= 0.94531
# Iter 134400, Minibatch Loss= 203.149292, Training Accuracy= 0.97656
# Iter 135680, Minibatch Loss= 75.437256, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 46.571060, Training Accuracy= 0.97656
# Iter 138240, Minibatch Loss= 315.632782, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 136.392029, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 9.215286, Training Accuracy= 0.99219
# Iter 142080, Minibatch Loss= 725.684326, Training Accuracy= 0.92969
# Iter 143360, Minibatch Loss= 60.690720, Training Accuracy= 0.99219
# Iter 144640, Minibatch Loss= 507.988098, Training Accuracy= 0.94531
# Iter 145920, Minibatch Loss= 109.238274, Training Accuracy= 0.96875
# Iter 147200, Minibatch Loss= 572.179810, Training Accuracy= 0.95312
# Iter 148480, Minibatch Loss= 204.763718, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 110.282707, Training Accuracy= 0.96094
# Iter 151040, Minibatch Loss= 222.399643, Training Accuracy= 0.97656
# Iter 152320, Minibatch Loss= 388.852234, Training Accuracy= 0.97656
# Iter 153600, Minibatch Loss= 231.694794, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 206.953873, Training Accuracy= 0.96094
# Iter 156160, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 157440, Minibatch Loss= 98.284393, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 161.522858, Training Accuracy= 0.98438
# Iter 160000, Minibatch Loss= 122.472672, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 107.356354, Training Accuracy= 0.96094
# Iter 162560, Minibatch Loss= 231.073242, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 155.381302, Training Accuracy= 0.96094
# Iter 165120, Minibatch Loss= 292.268616, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 122.976151, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 168960, Minibatch Loss= 157.893677, Training Accuracy= 0.95312
# Iter 170240, Minibatch Loss= 118.147232, Training Accuracy= 0.97656
# Iter 171520, Minibatch Loss= 85.767654, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 54.500687, Training Accuracy= 0.97656
# Iter 174080, Minibatch Loss= 219.678894, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 129.598358, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 92.330971, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 179200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 180480, Minibatch Loss= 238.813797, Training Accuracy= 0.97656
# Iter 181760, Minibatch Loss= 152.888962, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 39.489204, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 324.165894, Training Accuracy= 0.96094
# Iter 185600, Minibatch Loss= 32.433533, Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 335.054871, Training Accuracy= 0.97656
# Iter 188160, Minibatch Loss= 99.431923, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 188.156937, Training Accuracy= 0.97656
# Iter 190720, Minibatch Loss= 179.864731, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 228.083633, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 71.923447, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 195840, Minibatch Loss= 130.955444, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 11.094223, Training Accuracy= 0.99219
# Iter 198400, Minibatch Loss= 149.463715, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 282.213257, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.996094

# %% [markdown]
# [GitHub](https://github.com/PeterSansan) , [Blog](http://petersansan.top/)
