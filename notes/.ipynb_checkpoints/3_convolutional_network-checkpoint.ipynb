# %% [markdown]
# # CNN手写识别
# ```
# Author: PeterSansan
# Time : 2017-4-29
# ```
# 这个例子的数据输入输出是这样变化的：
# - 1）首先输入是一张28*28的图片
# - 2)第一层先通过一层卷积层，卷积层核大小为2x2，输出为32个通道（即32个特征），这样第一层卷积层输出后为[32,28,28]的数据，即可看成是32张图片 0 - 3)再经过2x2模板的最大池化，输出为[32,14,14]的数据，即下采样了一次
# - 4)第二层先通过一层卷积层，卷积层核大小为2x2，输出为64个通道（即64个特征），这样第二层卷积层输出为64x14x14的数据，即可看成是64张下采样后的图片
# - 5）再经过2x2模板的最大池化，输出为64x7x7的数据
# - 6)最后，把数据reshape展开一维数据[64x7x7]
# - 7)加一层dropout层
# - 8）输出为类别为10的softmax层

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./../mnist/MNIST_data/", one_hot=True)
# Out:
# Extracting ./../mnist/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./../mnist/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./../mnist/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./../mnist/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %% [markdown]
# ### 卷积和池化
# 这部分卷积最难理解
#
# TensorFlow在卷积和池化上有很强的灵活性。我们怎么处理边界？步长应该设多大？在这个实例里，我们会一直使用vanilla版本。我们的卷积使用1步长（stride size），0边距（padding size）的模板，保证输出和输入是同一个大小。我们的池化用简单传统的2x2大小的模板做max pooling。为了代码更简洁，我们把这部分抽象成一个函数。

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)    #这个卷积函数后面加入relu函数


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 20059.923828, Training Accuracy= 0.25000
# Iter 2560, Minibatch Loss= 6951.828125, Training Accuracy= 0.63281
# Iter 3840, Minibatch Loss= 4154.139648, Training Accuracy= 0.73438
# Iter 5120, Minibatch Loss= 3857.495117, Training Accuracy= 0.77344
# Iter 6400, Minibatch Loss= 3445.193359, Training Accuracy= 0.77344
# Iter 7680, Minibatch Loss= 2994.831787, Training Accuracy= 0.86719
# Iter 8960, Minibatch Loss= 3757.648926, Training Accuracy= 0.82812
# Iter 10240, Minibatch Loss= 1434.905762, Training Accuracy= 0.88281
# Iter 11520, Minibatch Loss= 3029.664551, Training Accuracy= 0.86719
# Iter 12800, Minibatch Loss= 2284.684570, Training Accuracy= 0.90625
# Iter 14080, Minibatch Loss= 1554.014771, Training Accuracy= 0.87500
# Iter 15360, Minibatch Loss= 593.826660, Training Accuracy= 0.92969
# Iter 16640, Minibatch Loss= 1743.803101, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 1524.146240, Training Accuracy= 0.88281
# Iter 19200, Minibatch Loss= 1042.923462, Training Accuracy= 0.92969
# Iter 20480, Minibatch Loss= 1330.911743, Training Accuracy= 0.92969
# Iter 21760, Minibatch Loss= 1894.114380, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1623.090576, Training Accuracy= 0.89844
# Iter 24320, Minibatch Loss= 2119.466797, Training Accuracy= 0.91406
# Iter 25600, Minibatch Loss= 1321.970703, Training Accuracy= 0.93750
# Iter 26880, Minibatch Loss= 1879.011230, Training Accuracy= 0.89844
# Iter 28160, Minibatch Loss= 903.011536, Training Accuracy= 0.93750
# Iter 29440, Minibatch Loss= 1738.521973, Training Accuracy= 0.88281
# Iter 30720, Minibatch Loss= 559.912781, Training Accuracy= 0.95312
# Iter 32000, Minibatch Loss= 940.111450, Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 1154.802002, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 1055.027222, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 1226.281372, Training Accuracy= 0.92188
# Iter 37120, Minibatch Loss= 1817.009766, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 1254.322510, Training Accuracy= 0.93750
# Iter 39680, Minibatch Loss= 939.093628, Training Accuracy= 0.91406
# Iter 40960, Minibatch Loss= 1164.351807, Training Accuracy= 0.92969
# Iter 42240, Minibatch Loss= 1238.979614, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 678.825684, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 421.823212, Training Accuracy= 0.92969
# Iter 46080, Minibatch Loss= 728.037781, Training Accuracy= 0.92188
# Iter 47360, Minibatch Loss= 941.236450, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 2962.362793, Training Accuracy= 0.87500
# Iter 49920, Minibatch Loss= 445.887207, Training Accuracy= 0.95312
# Iter 51200, Minibatch Loss= 725.513550, Training Accuracy= 0.92969
# Iter 52480, Minibatch Loss= 832.580505, Training Accuracy= 0.94531
# Iter 53760, Minibatch Loss= 514.181030, Training Accuracy= 0.96094
# Iter 55040, Minibatch Loss= 1149.389526, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 124.235542, Training Accuracy= 0.98438
# Iter 57600, Minibatch Loss= 1001.700562, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 391.705719, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 700.063354, Training Accuracy= 0.93750
# Iter 61440, Minibatch Loss= 300.533112, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 251.667938, Training Accuracy= 0.96875
# Iter 64000, Minibatch Loss= 440.663971, Training Accuracy= 0.97656
# Iter 65280, Minibatch Loss= 445.843170, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 430.061523, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 22.961426, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 120.204910, Training Accuracy= 0.97656
# Iter 70400, Minibatch Loss= 179.519791, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 531.186523, Training Accuracy= 0.96875
# Iter 72960, Minibatch Loss= 378.904114, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 496.707855, Training Accuracy= 0.92969
# Iter 75520, Minibatch Loss= 366.369324, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 113.726425, Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 331.458984, Training Accuracy= 0.94531
# Iter 79360, Minibatch Loss= 311.110565, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 425.480896, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 308.189392, Training Accuracy= 0.95312
# Iter 83200, Minibatch Loss= 573.541382, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 752.280151, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 673.669373, Training Accuracy= 0.92969
# Iter 87040, Minibatch Loss= 341.672302, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 703.375732, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 577.741943, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 428.059143, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 789.351440, Training Accuracy= 0.93750
# Iter 93440, Minibatch Loss= 430.504028, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 511.547333, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 227.943359, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 320.823364, Training Accuracy= 0.94531
# Iter 98560, Minibatch Loss= 417.058716, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 331.001984, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 297.417267, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 391.509888, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 268.102905, Training Accuracy= 0.96094
# Iter 104960, Minibatch Loss= 938.273926, Training Accuracy= 0.92969
# Iter 106240, Minibatch Loss= 344.553772, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 535.918762, Training Accuracy= 0.93750
# Iter 108800, Minibatch Loss= 63.144058, Training Accuracy= 0.99219
# Iter 110080, Minibatch Loss= 333.955261, Training Accuracy= 0.96094
# Iter 111360, Minibatch Loss= 584.327148, Training Accuracy= 0.93750
# Iter 112640, Minibatch Loss= 260.651337, Training Accuracy= 0.95312
# Iter 113920, Minibatch Loss= 170.492691, Training Accuracy= 0.98438
# Iter 115200, Minibatch Loss= 61.180511, Training Accuracy= 0.98438
# Iter 116480, Minibatch Loss= 135.837402, Training Accuracy= 0.97656
# Iter 117760, Minibatch Loss= 533.260437, Training Accuracy= 0.94531
# Iter 119040, Minibatch Loss= 210.599106, Training Accuracy= 0.99219
# Iter 120320, Minibatch Loss= 171.437805, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 232.238937, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 127.832443, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 752.576050, Training Accuracy= 0.93750
# Iter 125440, Minibatch Loss= 97.393570, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 129.890930, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 98.084839, Training Accuracy= 0.98438
# Iter 129280, Minibatch Loss= 154.749222, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 64.893875, Training Accuracy= 0.96875
# Iter 131840, Minibatch Loss= 322.342804, Training Accuracy= 0.95312
# Iter 133120, Minibatch Loss= 149.080032, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 183.120575, Training Accuracy= 0.95312
# Iter 135680, Minibatch Loss= 425.857971, Training Accuracy= 0.95312
# Iter 136960, Minibatch Loss= 168.506226, Training Accuracy= 0.95312
# Iter 138240, Minibatch Loss= 216.724365, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 327.243073, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 345.546509, Training Accuracy= 0.96875
# Iter 142080, Minibatch Loss= 372.864105, Training Accuracy= 0.96875
# Iter 143360, Minibatch Loss= 145.828293, Training Accuracy= 0.98438
# Iter 144640, Minibatch Loss= 178.361176, Training Accuracy= 0.96094
# Iter 145920, Minibatch Loss= 209.433105, Training Accuracy= 0.97656
# Iter 147200, Minibatch Loss= 45.058983, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 382.196350, Training Accuracy= 0.94531
# Iter 149760, Minibatch Loss= 44.396324, Training Accuracy= 0.99219
# Iter 151040, Minibatch Loss= 190.076721, Training Accuracy= 0.96875
# Iter 152320, Minibatch Loss= 375.223511, Training Accuracy= 0.96875
# Iter 153600, Minibatch Loss= 203.960709, Training Accuracy= 0.94531
# Iter 154880, Minibatch Loss= 264.085327, Training Accuracy= 0.96094
# Iter 156160, Minibatch Loss= 114.906082, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 107.743881, Training Accuracy= 0.99219
# Iter 158720, Minibatch Loss= 239.715637, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 44.780571, Training Accuracy= 0.99219
# Iter 161280, Minibatch Loss= 309.483185, Training Accuracy= 0.95312
# Iter 162560, Minibatch Loss= 83.995453, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 77.054794, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 32.299744, Training Accuracy= 0.98438
# Iter 166400, Minibatch Loss= 346.336304, Training Accuracy= 0.96875
# Iter 167680, Minibatch Loss= 224.205994, Training Accuracy= 0.95312
# Iter 168960, Minibatch Loss= 135.216522, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 209.030869, Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 212.594009, Training Accuracy= 0.96875
# Iter 172800, Minibatch Loss= 129.262329, Training Accuracy= 0.96094
# Iter 174080, Minibatch Loss= 190.945114, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 115.896790, Training Accuracy= 0.96875
# Iter 176640, Minibatch Loss= 308.535950, Training Accuracy= 0.94531
# Iter 177920, Minibatch Loss= 88.139465, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 334.676819, Training Accuracy= 0.96875
# Iter 180480, Minibatch Loss= 109.972458, Training Accuracy= 0.98438
# Iter 181760, Minibatch Loss= 91.215012, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 497.370056, Training Accuracy= 0.94531
# Iter 184320, Minibatch Loss= 164.734192, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 171.072128, Training Accuracy= 0.96875
# Iter 186880, Minibatch Loss= 100.219948, Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 73.415306, Training Accuracy= 0.98438
# Iter 189440, Minibatch Loss= 170.242004, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 180.892349, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 211.911255, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 80.746933, Training Accuracy= 0.96875
# Iter 194560, Minibatch Loss= 356.451477, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 91.009331, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 121.892792, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 225.971863, Training Accuracy= 0.96094
# Iter 199680, Minibatch Loss= 74.748337, Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy: 0.960938

# %% [markdown]
# [GitHub](https://github.com/PeterSansan) , [Blog](http://petersansan.top/)
